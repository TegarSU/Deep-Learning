# %%
from wordcloud import WordCloud, STOPWORDS 
import matplotlib.pyplot as plt 
import pandas as pd

# %%
clean_data = pd.read_csv("C:/xampp/htdocs/Deep-Learning/clean.csv",header=0)

clean_data.head()
# Out:
#                                                clean
# 0  lampu lintas jalan juanda veteran stasiun juan...
# 1  hormat pemprov jakarta jakarta guru bantu sd h...
# 2  kps camat patumbakkab deli serdang sumut desa ...
# 3  tolong angkut mikrolet jurus pademangan mangga...
# 4                                    bbm tuju rakyat

# %%
clean = clean_data.clean.values.tolist()

# for i in clean:
wordcloud = WordCloud(width = 1000, height = 1000, 
                background_color ='white', 
#                 stopwords = stopwords, 
                min_font_size = 10).generate(str(clean)) 
                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()
